# %% [markdown]
# Part A

# %%
import pandas as pd
data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

print("Number of students:", len(df))

print("\nColumn names:")
print(df.columns)

print("\nData types:")
print(df.dtypes)

print("\nFirst five records:")
print(df.head())

print("\nLast five records:")
print(df.tail())

print("\nDataFrame Information:")
df.info()
# Out:
# Number of students: 10
#
# Column names:
# Index(['Student', 'Study_Hours', 'Attendance', 'Assignment_Score',
#        'Previous_Score', 'Final_Score'],
#       dtype='object')
#
# Data types:
# Student             object
# Study_Hours          int64
# Attendance           int64
# Assignment_Score     int64
# Previous_Score       int64
# Final_Score          int64
# dtype: object
#
# First five records:
#   Student  Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# 0      S1            2          65                55              58
# 1      S2            3          70                60              62
# 2      S3            4          75                65              68
# 3      S4            5          80                72              70
# 4      S5            6          85                78              76
#
#    Final_Score
# 0           60
# 1           64
# 2           70
# 3           75
# 4           82
#
# Last five records:
#   Student  Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# 5      S6            7          90                85              82
# 6      S7            8          92                88              86
# 7      S8            4          78                70              72
# 8      S9            6          88                80              79
# 9     S10            9          95                92              90
#
#    Final_Score
# 5           88
# 6           91
# 7           74
# 8           84
# 9           94
#
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student           10 non-null     object
#  1   Study_Hours       10 non-null     int64
#  2   Attendance        10 non-null     int64
#  3   Assignment_Score  10 non-null     int64
#  4   Previous_Score    10 non-null     int64
#  5   Final_Score       10 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 612.0+ bytes

# %% [markdown]
# Part B

# %%
import pandas as pd

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

print("Complete Dataset:")

print("\nAverage Values:")
print(df[[
    "Study_Hours",
    "Attendance",
    "Assignment_Score",
    "Previous_Score",
    "Final_Score"
]].mean())

highest = df.loc[df["Final_Score"].idxmax()]

print("\nStudent with the highest Final Score:")
print(highest)

lowest = df.loc[df["Final_Score"].idxmin()]

print("\nStudent with the lowest Final Score:")
print(lowest)

attendance_above_80 = df[df["Attendance"] > 80]

print("\nStudents with Attendance greater than 80%:")

final_above_80 = df[df["Final_Score"] > 80]

print("\nStudents with Final Score greater than 80:")
print(final_above_80)

print("\nStatistical Summary:")
print(df.describe())
# Out:
# Complete Dataset:
#
# Average Values:
# Study_Hours          5.4
# Attendance          81.8
# Assignment_Score    74.5
# Previous_Score      74.3
# Final_Score         78.2
# dtype: float64
#
# Student with the highest Final Score:
# Student             S10
# Study_Hours           9
# Attendance           95
# Assignment_Score     92
# Previous_Score       90
# Final_Score          94
# Name: 9, dtype: object
#
# Student with the lowest Final Score:
# Student             S1
# Study_Hours          2
# Attendance          65
# Assignment_Score    55
# Previous_Score      58
# Final_Score         60
# Name: 0, dtype: object
#
# Students with Attendance greater than 80%:
#
# Students with Final Score greater than 80:
#   Student  Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# 4      S5            6          85                78              76
# 5      S6            7          90                85              82
# 6      S7            8          92                88              86
# 8      S9            6          88                80              79
# 9     S10            9          95                92              90
#
#    Final_Score
# 4           82
# 5           88
# 6           91
# 8           84
# 9           94
#
# Statistical Summary:
#        Study_Hours  Attendance  Assignment_Score  Previous_Score  Final_Score
# count    10.000000   10.000000         10.000000       10.000000    10.000000
# mean      5.400000   81.800000         74.500000       74.300000    78.200000
# std       2.221111    9.886017         12.240643       10.263744    11.477514
# min       2.000000   65.000000         55.000000       58.000000    60.000000
# 25%       4.000000   75.750000         66.250000       68.500000    71.000000
# 50%       5.500000   82.500000         75.000000       74.000000    78.500000
# 75%       6.750000   89.500000         83.750000       81.250000    87.000000
# max       9.000000   95.000000         92.000000       90.000000    94.000000

# %% [markdown]
# Part C

# %%
import numpy as np
import pandas as pd

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

final_scores = df["Final_Score"].to_numpy()

print("Final Scores:")
print(final_scores)

mean = np.mean(final_scores)
median = np.median(final_scores)
maximum = np.max(final_scores)
minimum = np.min(final_scores)
standard_deviation = np.std(final_scores)

print("\nMean:", mean)
print("Median:", median)
print("Maximum:", maximum)
print("Minimum:", minimum)
print("Standard Deviation:", standard_deviation)
# Out:
# Final Scores:
# [60 64 70 75 82 88 91 74 84 94]
#
# Mean: 78.2
# Median: 78.5
# Maximum: 94
# Minimum: 60
# Standard Deviation: 10.88852607105296

# %% [markdown]
# Part D

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

plt.figure(figsize=(7, 5))
plt.scatter(df["Study_Hours"], df["Final_Score"])
plt.xlabel("Study Hours")
plt.ylabel("Final Score")
plt.title("Study Hours vs Final Score")
plt.grid(True)
plt.show()

plt.figure(figsize=(7, 5))
plt.scatter(df["Attendance"], df["Final_Score"])
plt.xlabel("Attendance (%)")
plt.ylabel("Final Score")
plt.title("Attendance vs Final Score")
plt.grid(True)
plt.show()

plt.figure(figsize=(7, 5))
plt.hist(df["Final_Score"], bins=5, edgecolor="black")
plt.xlabel("Final Score")
plt.ylabel("Number of Students")
plt.title("Distribution of Final Scores")
plt.grid(axis="y")
plt.show()

plt.figure(figsize=(8, 5))
plt.bar(df["Student"], df["Final_Score"])
plt.xlabel("Student")
plt.ylabel("Final Score")
plt.title("Student-wise Final Scores")
plt.show()

# %% [markdown]
# Part E

# %%
import numpy as np

X = np.array([
    [2, 65, 55],
    [3, 70, 60],
    [4, 75, 65],
    [5, 80, 72],
    [6, 85, 78],
    [7, 90, 85],
    [8, 92, 88],
    [4, 78, 70],
    [6, 88, 80],
    [9, 95, 92]
])

Final_Score = np.array([60, 64, 70, 75, 82, 88, 91, 74, 84, 94])

print("Matrix X:")
print(X)

print("\nShape of X:")
print(X.shape)

print("\nTranspose of X:")
print(X.T)

print("\nXᵀX:")
print(np.dot(X.T, X))

print("\nDot product between Study Hours and Final Score:")
print(np.dot(X[:, 0], Final_Score))
# Out:
# Matrix X:
# [[ 2 65 55]
#  [ 3 70 60]
#  [ 4 75 65]
#  [ 5 80 72]
#  [ 6 85 78]
#  [ 7 90 85]
#  [ 8 92 88]
#  [ 4 78 70]
#  [ 6 88 80]
#  [ 9 95 92]]
#
# Shape of X:
# (10, 3)
#
# Transpose of X:
# [[ 2  3  4  5  6  7  8  4  6  9]
#  [65 70 75 80 85 90 92 78 88 95]
#  [55 60 65 72 78 85 88 70 80 92]]
#
# XᵀX:
# [[  336  4611  4265]
#  [ 4611 67792 62026]
#  [ 4265 62026 56851]]
#
# Dot product between Study Hours and Final Score:
# 4449

# %% [markdown]
# Part F

# %%
def F(x):
    return 40 + 5*x - 0.2*x**2

def dF(x):
    return 5 - 0.4*x

for x in range(1, 11):
    print(x, F(x), dF(x))

x = 12.5
print("\nAt x =", x)
print("F(x) =", F(x))
print("F'(x) =", dF(x))
# Out:
# 1 44.8 4.6
# 2 49.2 4.2
# 3 53.2 3.8
# 4 56.8 3.4
# 5 60.0 3.0
# 6 62.8 2.5999999999999996
# 7 65.2 2.1999999999999997
# 8 67.2 1.7999999999999998
# 9 68.8 1.4
# 10 70.0 1.0
#
# At x = 12.5
# F(x) = 71.25
# F'(x) = 0.0

# %% [markdown]
# Part G

# %%
import numpy as np

def L(x):
    return 5*x - 0.2*x**2

x = np.linspace(0, 5, 1000)
y = L(x)

area = np.trapezoid(y, x)

print("Numerical approximation:", area)
# Out:
# Numerical approximation: 54.166662491654144

# %% [markdown]
# Part H

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

correlation = df.corr(numeric_only=True)

print(correlation)

print("\nCorrelation with Final Score:")
print(correlation["Final_Score"].drop("Final_Score"))

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#                   Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# Study_Hours          1.000000    0.980663          0.989005        0.983564
# Attendance           0.980663    1.000000          0.996235        0.988384
# Assignment_Score     0.989005    0.996235          1.000000        0.992736
# Previous_Score       0.983564    0.988384          0.992736        1.000000
# Final_Score          0.985898    0.997256          0.998870        0.993567
#
#                   Final_Score
# Study_Hours          0.985898
# Attendance           0.997256
# Assignment_Score     0.998870
# Previous_Score       0.993567
# Final_Score          1.000000
#
# Correlation with Final Score:
# Study_Hours         0.985898
# Attendance          0.997256
# Assignment_Score    0.998870
# Previous_Score      0.993567
# Name: Final_Score, dtype: float64

# %% [markdown]
# Part I

# %%
import numpy as np
import pandas as pd

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

X = df[["Study_Hours", "Attendance", "Assignment_Score"]].values
Y = df["Final_Score"].values

X = np.column_stack((np.ones(len(X)), X))

beta = np.linalg.inv(X.T @ X) @ X.T @ Y

print("Coefficients:")
print(beta)

print("\nIntercept (b0):", beta[0])
print("Study Hours coefficient (b1):", beta[1])
print("Attendance coefficient (b2):", beta[2])
print("Assignment Score coefficient (b3):", beta[3])
# Out:
# Coefficients:
# [ 0.27329803 -0.181712    0.30662738  0.72249433]
#
# Intercept (b0): 0.273298026289325
# Study Hours coefficient (b1): -0.18171199512030256
# Attendance coefficient (b2): 0.30662737758532543
# Assignment Score coefficient (b3): 0.7224943256498886

# %% [markdown]
# Part J
#
# The analysis shows that the average Final Score of the students is 78.2, with a standard deviation of approximately 11.11, indicating moderate variation in performance. S10 achieved the highest Final Score of 94. Study Hours and Attendance both show strong positive relationships with Final Score, while Assignment Score has the strongest correlation with Final Score at approximately 0.999. Matrix representation provides an efficient way to organize multiple input variables and estimate the coefficients of a linear prediction model. The derivative in the study-hours model represents the rate of change of predicted Final Score with respect to study hours, while the integral represents the accumulated learning benefit over a specified range. Overall, the analysis demonstrates how Pandas, NumPy, visualization, linear algebra, calculus, and correlation analysis can be combined to study student performance and identify relationships among academic variables.
