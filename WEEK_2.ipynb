# %%
import datetime
import random
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

# %%
import datetime
import random
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

# %%
try:
    x = int(input("Enter a number: "))
    print("You entered:", x)
except ValueError:
    print("That was not a valid number!")
# Out:
# Enter a number: 34
# You entered: 34

# %%
try:
    num = int(input("Enter a number to divide 100: "))
    result = 100 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Not a number.")
else:
    print("Result is:", result)
finally:
    print("Execution complete. This block always runs.")

# %%
try:
    a = int("ten")
    b = 10 / 0
except (ValueError, ZeroDivisionError) as e:
    print("An error occurred:", e)

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-5)
except ValueError as e:
    print("Caught an exception:", e)

# %%
def divide(a, b):
    print(f"Dividing {a} by {b}")

print(divide(10, 2))

# %%
import traceback

try:
    result = 10 / 0
except Exception as e:
    print("Something went wrong.")
    traceback.print_exc()

# %% [markdown]
# #🛠️ C. Using the Python Debugger (pdb)

# %%
def calculate_total(price, quantity):
    return price * quantity

print(calculate_total(50, 2))

# %% [markdown]
# # 1.1 Generate a list of 100 simulated sensor readings.
# #    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
# #    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
# #    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
# #    - device_type: Randomly chosen from DEVICE_TYPES.
# #    - location: Randomly chosen from LOCATIONS.
# #    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# # Store these in a list called 'raw_sensor_data'.
#
# # Your code for Task 1.1 here:

# %%
import datetime
import random
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )
    print(raw_sensor_data[:5])
# Out:
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 08:57:25', 'DEV002', 'Humidity', 'Office B', 33.54), ('2026-07-20 08:58:25', 'DEV003', 'Pressure', 'Office B', 1037.38), ('2026-07-20 08:59:25', 'DEV004', 'Temperature', 'Office B', 27.42), ('2026-07-20 09:00:25', 'DEV005', 'Pressure', 'Office B', 1032.59)]

# %% [markdown]
# # 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
# #     where 'device_type' is 'Temperature_Sensor'.
# #     Each item in 'temperature_readings' should be a dictionary with keys:
# #     'timestamp', 'device_id', 'location', 'temperature_celsius'.
#
# # Your code for Task 1.2 here:

# %%
temperature_readings = []

for timestamp, device_id, device_type, location, value in raw_sensor_data:
    if device_type == 'Temperature':
        temperature_readings.append({
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })

print(temperature_readings[:5])
# Out:
# [{'timestamp': '2026-07-20 08:59:25', 'device_id': 'DEV004', 'location': 'Office B', 'temperature_celsius': 27.42}, {'timestamp': '2026-07-20 09:03:25', 'device_id': 'DEV008', 'location': 'Office B', 'temperature_celsius': 33.28}, {'timestamp': '2026-07-20 09:04:25', 'device_id': 'DEV009', 'location': 'Office B', 'temperature_celsius': 24.62}, {'timestamp': '2026-07-20 09:05:25', 'device_id': 'DEV010', 'location': 'Warehouse', 'temperature_celsius': 19.56}, {'timestamp': '2026-07-20 09:22:25', 'device_id': 'DEV027', 'location': 'Office A', 'temperature_celsius': 18.26}]

# %% [markdown]
# # 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
#
# # Your code for Task 1.3 here:

# %%
unique_locations = set()

for _, _, _, location, _ in raw_sensor_data:
    unique_locations.add(location)

print(unique_locations)
# Out:
# {'Office B', 'Office A', 'Server Room', 'Warehouse'}

# %% [markdown]
# # 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
# #     a tuple: (min_value, max_value) observed for that device type across all readings.
# #     Initialize with sensible large/small values.
#
# # Your code for Task 1.4 here:

# %%
device_stats = {}

for d_type in DEVICE_TYPES:
    device_stats[d_type] = (float('inf'), float('-inf'))

for _, _, device_type, _, value in raw_sensor_data:
    current_min, current_max = device_stats[device_type]
    new_min = min(current_min, value)
    new_max = max(current_max, value)
    device_stats[device_type] = (new_min, new_max)


print(device_stats)
# Out:
# {'Temperature': (16.15, 34.84), 'Humidity': (30.64, 69.91), 'Pressure': (950.89, 1048.99)}

# %% [markdown]
# # 1.5: Advanced Indexing and Slicing (Lists and Strings)
# print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
#
# # Let's use 'raw_sensor_data' and create a sample string for these tasks.
# sample_string = "PythonProgrammingIsFun"
#
# # 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
# #       Store the result in 'sliced_readings_1'.
# #       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
# #       Store the result in 'sliced_readings_2'.
#
# # Your code for Task 1.5.1 here:

# %%
sliced_readings_1 = raw_sensor_data[9:20]

sliced_readings_2 = raw_sensor_data[::5]

print("Sliced Readings 1 (10th to 20th inclusive):")
print(sliced_readings_1)
print("\nSliced Readings 2 (every 5th reading):")
print(sliced_readings_2)
# Out:
# Sliced Readings 1 (10th to 20th inclusive):
# [('2026-07-20 09:05:25', 'DEV010', 'Temperature', 'Warehouse', 19.56), ('2026-07-20 09:06:25', 'DEV011', 'Pressure', 'Office A', 1045.91), ('2026-07-20 09:07:25', 'DEV012', 'Humidity', 'Warehouse', 60.98), ('2026-07-20 09:08:25', 'DEV013', 'Humidity', 'Warehouse', 63.41), ('2026-07-20 09:09:25', 'DEV014', 'Pressure', 'Warehouse', 1041.78), ('2026-07-20 09:10:25', 'DEV015', 'Humidity', 'Office B', 45.56), ('2026-07-20 09:11:25', 'DEV016', 'Humidity', 'Warehouse', 50.76), ('2026-07-20 09:12:25', 'DEV017', 'Pressure', 'Office A', 954.69), ('2026-07-20 09:13:25', 'DEV018', 'Pressure', 'Office A', 1044.47), ('2026-07-20 09:14:25', 'DEV019', 'Humidity', 'Office A', 36.5), ('2026-07-20 09:15:25', 'DEV020', 'Pressure', 'Server Room', 960.37)]
#
# Sliced Readings 2 (every 5th reading):
# [('2026-07-20 08:56:25', 'DEV001', 'Pressure', 'Warehouse', 1007.05), ('2026-07-20 09:01:25', 'DEV006', 'Pressure', 'Warehouse', 950.89), ('2026-07-20 09:06:25', 'DEV011', 'Pressure', 'Office A', 1045.91), ('2026-07-20 09:11:25', 'DEV016', 'Humidity', 'Warehouse', 50.76), ('2026-07-20 09:16:25', 'DEV021', 'Pressure', 'Server Room', 1012.42), ('2026-07-20 09:21:25', 'DEV026', 'Humidity', 'Server Room', 36.08), ('2026-07-20 09:26:25', 'DEV031', 'Temperature', 'Server Room', 29.92), ('2026-07-20 09:31:25', 'DEV036', 'Pressure', 'Office B', 1010.41), ('2026-07-20 09:36:25', 'DEV041', 'Pressure', 'Warehouse', 961.08), ('2026-07-20 09:41:25', 'DEV046', 'Pressure', 'Server Room', 958.15), ('2026-07-20 09:46:25', 'DEV051', 'Temperature', 'Office A', 26.25), ('2026-07-20 09:51:25', 'DEV056', 'Humidity', 'Server Room', 56.25), ('2026-07-20 09:56:25', 'DEV061', 'Temperature', 'Office A', 30.52), ('2026-07-20 10:01:25', 'DEV066', 'Humidity', 'Office B', 61.59), ('2026-07-20 10:06:25', 'DEV071', 'Pressure', 'Server Room', 955.55), ('2026-07-20 10:11:25', 'DEV076', 'Humidity', 'Office A', 66.97), ('2026-07-20 10:16:25', 'DEV081', 'Humidity', 'Warehouse', 45.96), ('2026-07-20 10:21:25', 'DEV086', 'Temperature', 'Server Room', 16.15), ('2026-07-20 10:26:25', 'DEV091', 'Humidity', 'Office A', 60.62), ('2026-07-20 10:31:25', 'DEV096', 'Temperature', 'Office A', 19.59)]

# %% [markdown]
# # 1.5.2 String Slicing: Extract a substring from the 7th to the 17th character (inclusive) from 'sample_string'.
# #       Store the result in 'sliced_string_1'.
# #       Then, extract every 2nd character from 'sample_string' starting from the beginning.
# #       Store the result in 'sliced_string_2'.
#
# # Your code for Task 1.5.2 here:

# %%
sample_string = "PythonProgrammingIsFun"

sliced_string_1 = sample_string[6:17]

sliced_string_2 = sample_string[::2]

print("Sliced String 1 (7th to 17th inclusive):")
print(sliced_string_1)
print("\nSliced String 2 (every 2nd character):")
print(sliced_string_2)
# Out:
# Sliced String 1 (7th to 17th inclusive):
# Programming
#
# Sliced String 2 (every 2nd character):
# PtoPormigsu

# %% [markdown]
# # 1.5.2 String Slicing: Extract a substring from the 7th to the 17th character (inclusive) from 'sample_string'.
# #       Store the result in 'sliced_string_1'.
# #       Then, extract every 2nd character from 'sample_string' starting from the beginning.
# #       Store the result in 'sliced_string_2'.
#
# # Your code for Task 1.5.2 here:

# %%
sample_string = "PythonProgrammingIsFun"

sliced_string_1 = sample_string[6:17]

sliced_string_2 = sample_string[::2]

print("Sliced String 1 (7th to 17th inclusive):")
print(sliced_string_1)
print("\nSliced String 2 (every 2nd character):")
print(sliced_string_2)
# Out:
# Sliced String 1 (7th to 17th inclusive):
# Programming
#
# Sliced String 2 (every 2nd character):
# PtoPormigsu

# %% [markdown]
# # 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
# #       Store it in 'fifth_reading_device_type'.
# #       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
# #       Store it in 'device_type_suffix'.
#
# # Your code for Task 1.5.3 here:

# %%
fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print(f"Device type of 5th reading: {fifth_reading_device_type}")
print(f"Suffix of device type: {device_type_suffix}")
# Out:
# Device type of 5th reading: Pressure
# Suffix of device type: essure

# %% [markdown]
# # --- Task 2: Writing and Using Functions in Python ---
# print("\n--- Task 2: Function Definitions and Usage ---")
#
# # 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
# #     that takes the 'raw_sensor_data' list and a 'target_location' string.
# #     It should return a list of all readings (as tuples) for that specific location.
#
# # Your code for Task 2.1 here:

# %%
def get_readings_by_location(readings_list, target_location):
    """
    Filters a list of sensor readings to return only those for a specific location.

    Args:
        readings_list (list): A list of sensor readings, where each reading is a tuple
                            (timestamp, device_id, device_type, location, value).
        target_location (str): The location to filter by.

    Returns:
        list: A new list containing only the readings (as tuples) that match the target_location.
    """
    readings_for_location = []
    for reading in readings_list:
        if reading[3] == target_location:
            readings_for_location.append(reading)
    return readings_for_location

# %%
warehouse_readings = get_readings_by_location(raw_sensor_data, 'Warehouse')
print(f"\nFirst 5 readings for 'Warehouse':")
print(warehouse_readings[:5])
print(f"Total readings for 'Warehouse': {len(warehouse_readings)}")
# Out:
# First 5 readings for 'Warehouse':
# [('2026-07-20 09:05:50', 'DEV002', 'Temperature', 'Warehouse', 17.7), ('2026-07-20 09:06:50', 'DEV003', 'Humidity', 'Warehouse', 60.55), ('2026-07-20 09:08:50', 'DEV005', 'Temperature', 'Warehouse', 30.76), ('2026-07-20 09:10:50', 'DEV007', 'Humidity', 'Warehouse', 46.47), ('2026-07-20 09:11:50', 'DEV008', 'Humidity', 'Warehouse', 59.99)]
# Total readings for 'Warehouse': 24

# %% [markdown]
# # 2.2 Write a function `calculate_average_temperature(temp_data_list)`
# #     that takes the 'temperature_readings' list (list of dictionaries).
# #     It should calculate and return the average temperature. Return 0.0 if the list is empty.
#
# # Your code for Task 2.2 here:

# %%
def calculate_average_temperature(temp_data_list):
    """
    Calculates the average temperature from a list of temperature reading dictionaries.

    Args:
        temp_data_list (list): A list of dictionaries, where each dictionary
                                contains a 'temperature_celsius' key.

    Returns:
        float: The average temperature, or 0.0 if the list is empty.
    """
    if not temp_data_list:
        return 0.0

    total_temperature = sum(reading['temperature_celsius'] for reading in temp_data_list)
    return total_temperature / len(temp_data_list)

# %%
average_temp = calculate_average_temperature(temperature_readings)
print(f"\nAverage Temperature: {average_temp:.2f} °C")

empty_temp_list = []
average_temp_empty = calculate_average_temperature(empty_temp_list)
print(f"Average Temperature (empty list): {average_temp_empty:.2f} °C")
# Out:
# Average Temperature: 26.25 °C
# Average Temperature (empty list): 0.00 °C

# %% [markdown]
# # 2.3 Write a function `generate_report_line(reading_dict)`
# #     that takes a single temperature reading dictionary.
# #     It should return a formatted string like:
# #     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
#
# # Your code for Task 2.3 here:

# %%
def generate_report_line(reading_dict):
    """
    Generates a formatted report string for a single temperature reading.

    Args:
        reading_dict (dict): A dictionary representing a temperature reading,
                             expected to have 'timestamp', 'device_id', 'location',
                             and 'temperature_celsius' keys.

    Returns:
        str: A formatted string like "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
    """
    timestamp = reading_dict['timestamp']
    device_id = reading_dict['device_id']
    location = reading_dict['location']
    temperature = reading_dict['temperature_celsius']
    return f"[{timestamp}] Device {device_id} at {location}: {temperature}°C"

# %%
if temperature_readings
    report_line = generate_report_line(sample_reading)
    print(f"\nSample Report Line:\n{report_line}")
else:
    print("No temperature readings available to generate a report line.")
# Out:
# Sample Report Line:
# [2026-07-20 08:59:25] Device DEV004 at Office B: 27.42°C

# %% [markdown]
# # --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
# print("\n--- Task 3: Core Library Usage ---")
#
# # 3.1 Use the `os` module to create a new directory named 'sensor_reports'
# #     in the current working directory, if it doesn't already exist.
#
# # Your code for Task 3.1 here:

# %%
import os

reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %% [markdown]
# # 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
# #     Convert string timestamps to datetime objects first.
# #     Print the duration in days, hours, and minutes.
#
# # Your code for Task 3.2 here:

# %%
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]


    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 1 hours, 39 minutes.

# %% [markdown]
# # 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
# #     using the `random` module. Store it in 'random_values'.
#
# # Your code for Task 3.3 here:

# %%
import random

random_values = [random.randint(100, 200) for _ in range(5)]

print("Generated random values:", random_values)
# Out:
# Generated random values: [183, 126, 155, 198, 103]

# %% [markdown]
# # --- Task 4: File Handling in Python ---
# print("\n--- Task 4: File I/O ---")
#
# # 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
# #     Each line in the file should be generated using the `generate_report_line` function.
#
# # Your code for Task 4.1 here:

# %%
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

# %% [markdown]
# # 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
# #     named 'read_report_lines'. Print the first 3 lines.
#
# # Your code for Task 4.2 here:

# %%
import os

reports_dir = 'sensor_reports'
report_filename = os.path.join(reports_dir, 'temperature_report.txt')

read_report_lines = []
if not os.path.exists(report_filename):
    print(f"\nError: The file '{report_filename}' was not found. Please ensure Task 4.1 (writing the report) has been executed successfully.")
else:
    try:
        with open(report_filename, 'r') as f:
            read_report_lines = f.readlines()
        print(f"\nContent of '{report_filename}' (first 3 lines):")
        for line in read_report_lines[:3]:
            print(line.strip())
    except IOError as e:
        print(f"\nError reading file '{report_filename}': {e}")
# Out:
# Error: The file 'sensor_reports/temperature_report.txt' was not found.
